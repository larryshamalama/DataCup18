# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
performance  = pd.read_csv('performance_train.csv')
facturation  = pd.read_csv('facturation_train.csv')
payments     = pd.read_csv('paiements_train.csv')
transactions = pd.read_csv('transactions_train.csv')

customer_ids = performance['ID_CPTE']

print('Proportion of clients who default:', sum(performance['Default'])/len(performance))
# Out:
# Proportion of clients who default: 0.19336134453781512

# %%
customer_ids
# Out:
# 0        99690111
# 1        57427180
# 2        29617912
# 3        61632809
# 4        14117855
# 5        23700394
# 6        27881705
# 7        46100731
# 8        58512689
# 9        24661392
# 10       39254190
# 11       95779116
# 12       26016069
# 13       47119980
# 14       55240199
# 15       35559686
# 16       71856405
# 17       75085501
# 18       75780289
# 19       74010769
# 20       90088004
# 21       43551724
# 22       68131233
# 23       46775121
# 24       71339428
# 25       58307978
# 26       19692826
# 27       64460984
# 28       36560668
# 29       83467452
#            ...
# 11870    91285968
# 11871    79958539
# 11872    85761545
# 11873    39420868
# 11874    89131001
# 11875    35971151
# 11876    19611689
# 11877    61818099
# 11878    71673781
# 11879    65865490
# 11880    35031952
# 11881    18627710
# 11882    30919148
# 11883    76340293
# 11884    75929799
# 11885    27910976
# 11886    76285913
# 11887    95253759
# 11888    59138634
# 11889    33262553
# 11890    94792460
# 11891    64408324
# 11892    42544187
# 11893    66101999
# 11894    97501424
# 11895    58923219
# 11896    40478502
# 11897    97548597
# 11898    12603910
# 11899    11346742
# Name: ID_CPTE, Length: 11900, dtype: int64

# %% [markdown]
# # Raw Data Preview

# %% [markdown]
# #### Performance

# %%
performance.head()
# Out:
#     ID_CPTE PERIODID_MY  Default
# 0  99690111  2015-12-01        0
# 1  57427180  2012-12-01        0
# 2  29617912  2015-12-01        0
# 3  61632809  2015-12-01        0
# 4  14117855  2013-12-01        0

# %% [markdown]
# #### Facturation

# %%
facturation.head()
# Out:
#     ID_CPTE PERIODID_MY StatementDate  CurrentTotalBalance  CashBalance  \
# 0  99690111  2015-05-01    2015-05-03              8497.84      4293.12
# 1  99690111  2014-11-01    2014-11-03               866.00         0.00
# 2  99690111  2015-06-01    2015-05-31             10790.95      5224.44
# 3  99690111  2015-10-01    2015-10-04             12388.46      4786.08
# 4  99690111  2015-11-01    2015-11-02             12746.50      4818.48
#
#    CreditLimit  DelqCycle
# 0      16200.0          0
# 1      12000.0          0
# 2      16200.0          0
# 3      16200.0          0
# 4      16200.0          0

# %% [markdown]
# #### Payments

# %%
payments.head()
# Out:
#     ID_CPTE  TRANSACTION_AMT     TRANSACTION_DTTM PAYMENT_REVERSAL_XFLG
# 0  99690111            208.0  2015-04-26 00:00:00                     Q
# 1  99690111            176.8  2015-05-28 00:00:00                     Q
# 2  99690111            200.0  2015-03-27 04:00:00                     Q
# 3  99690111             80.8  2015-04-02 00:00:00                     Q
# 4  99690111            250.0  2015-11-24 00:00:00                     Q

# %% [markdown]
# #### Transactions

# %%
transactions.head()
# Out:
#     ID_CPTE MERCHANT_CATEGORY_XCD  MERCHANT_CITY_NAME MERCHANT_COUNTRY_XCD  \
# 0  99690111                     A              365767                   DP
# 1  99690111                     L             2635650                   DP
# 2  99690111                     L             2635650                   DP
# 3  99690111                     J              680536                   AF
# 4  99690111                     J              680536                   AF
#
#   DECISION_XCD  PRIOR_CREDIT_LIMIT_AMT  TRANSACTION_AMT  \
# 0            C                  5927.0            52.53
# 1            C                 13343.0            28.35
# 2            C                 13343.0             0.00
# 3            C                  9430.0             0.00
# 4            C                 10600.0             0.00
#
#   TRANSACTION_CATEGORY_XCD     TRANSACTION_DTTM TRANSACTION_TYPE_XCD SICGROUP
# 0                        E  2015-06-20 12:00:00                    F       AN
# 1                        B  2015-01-25 12:00:00                    F       AN
# 2                        A  2015-01-26 12:00:00                    G       AN
# 3                        A  2015-03-25 08:00:00                    G       AW
# 4                        A  2015-03-03 08:00:00                    G       AW

# %%
list(performance[performance['ID_CPTE'] == 57427180]['PERIODID_MY'])
# Out:
# ['2012-12-01']

# %%
print('performance length:\t', len(performance))
print('facturation length:\t', len(facturation))
print('payments length:\t', len(payments))
print('transactions length:\t', len(transactions))
print('')
print('performance clients:\t', len(set(performance['ID_CPTE'])))
print('facturation clients:\t', len(set(facturation['ID_CPTE'])))
print('payments clients:\t', len(set(payments['ID_CPTE'])))
print('transactions clients:\t', len(set(transactions['ID_CPTE'])))
# Out:
# performance length:	 11900
# facturation length:	 166543
# payments length:	 292320
# transactions length:	 690730
#
# performance clients:	 11900
# facturation clients:	 11900
# payments clients:	 11900
# transactions clients:	 3769

# %%
class customer:
    
    def __init__(self, customer_id, performance, facturation, payments, transactions):
        
        self.customer_id  = customer_id
        self.performance  = performance
        self.facturation  = facturation
        self.payments     = payments
        self.transactions = transactions
        
        self.assessment = list(performance['PERIODID_MY'])[0]
        self.default    = list(performance['Default'])[0]

# %%
def generate_clients(customer_ids, *dfs):

    for cus in customer_ids:
        yield [cus] + [df[df['ID_CPTE'] == cus] for df in dfs]

# %%
performance[performance['ID_CPTE'] == 99690111]
# Out:
#     ID_CPTE PERIODID_MY  Default
# 0  99690111  2015-12-01        0

# %%
client_generator = generate_clients(customer_ids, performance, facturation, payments, transactions)
clients = [customer(*client_info) for client_info in client_generator]

# %% [markdown]
# ## Notes
#
# - All ```PERIODID_MY``` occur on the 1st day of a given month, i.e. ```PERIODID_MY = 201X-XX-01```.

# %% [markdown]
# #### Performance

# %%
performance[performance['ID_CPTE'] == 97350991]
# Out:
#       ID_CPTE PERIODID_MY  Default
# 111  97350991  2014-12-01        0

# %%
performance[performance['Default'] == 1]['ID_CPTE']
# Out:
# 18       75780289
# 53       58022132
# 56       25809739
# 72       35143533
# 137      94504449
# 208      59776762
# 232      28710728
# 302      84279471
# 320      65860216
# 338      57628717
# 343      77812300
# 378      95510550
# 392      87585811
# 396      34387541
# 397      96973042
# 408      54089455
# 410      25129943
# 447      94147317
# 457      63791520
# 468      22778169
# 475      41993838
# 480      16760642
# 481      52928938
# 496      45966791
# 499      96393416
# 503      53009046
# 519      57674316
# 526      55898522
# 530      48691364
# 533      74195986
#            ...
# 11636    50150261
# 11640    77873904
# 11641    27164284
# 11642    56583098
# 11645    50599840
# 11646    25786707
# 11659    90609839
# 11662    83082256
# 11665    42799600
# 11672    72039172
# 11675    82211560
# 11677    40045534
# 11690    29769282
# 11692    51056864
# 11698    37270667
# 11725    93978689
# 11747    91614260
# 11752    55794342
# 11769    24961423
# 11776    27405020
# 11784    35900438
# 11791    14424318
# 11793    19242606
# 11794    28244726
# 11815    33525197
# 11842    33276275
# 11844    17246537
# 11850    99035230
# 11856    63153473
# 11897    97548597
# Name: ID_CPTE, Length: 2301, dtype: int64

# %%
clients[0].performance
# Out:
#     ID_CPTE PERIODID_MY  Default
# 0  99690111  2015-12-01        0

# %% [markdown]
# #### Facturation

# %%
facturation['DelqCycle'].value_counts()
# Out:
# 0    157173
# 1      7899
# 2      1285
# 3       151
# 4        30
# 5         5
# Name: DelqCycle, dtype: int64

# %%
clients[0].facturation.sort_values(by=['PERIODID_MY'])
# Out:
#      ID_CPTE PERIODID_MY StatementDate  CurrentTotalBalance  CashBalance  \
# 1   99690111  2014-11-01    2014-11-03               866.00         0.00
# 7   99690111  2014-12-01    2014-12-03              1151.85         0.00
# 10  99690111  2015-01-01    2015-01-02              2298.96       350.00
# 8   99690111  2015-02-01    2015-01-31              4045.67      1148.45
# 11  99690111  2015-03-01    2015-03-03              5926.20      2567.25
# 12  99690111  2015-04-01    2015-03-31              6916.62      3307.33
# 0   99690111  2015-05-01    2015-05-03              8497.84      4293.12
# 2   99690111  2015-06-01    2015-05-31             10790.95      5224.44
# 13  99690111  2015-07-01    2015-07-05             10560.00      5127.54
# 5   99690111  2015-08-01    2015-08-02             10610.05      4753.35
# 6   99690111  2015-09-01    2015-08-30             11417.12      4616.46
# 3   99690111  2015-10-01    2015-10-04             12388.46      4786.08
# 4   99690111  2015-11-01    2015-11-02             12746.50      4818.48
# 9   99690111  2015-12-01    2015-11-30             13119.60      4791.44
#
#     CreditLimit  DelqCycle
# 1       12000.0          0
# 7       12000.0          0
# 10      12000.0          0
# 8       16200.0          0
# 11      16200.0          0
# 12      16200.0          0
# 0       16200.0          0
# 2       16200.0          0
# 13      16200.0          0
# 5       16200.0          0
# 6       16200.0          0
# 3       16200.0          0
# 4       16200.0          0
# 9       16200.0          0

# %% [markdown]
# #### Payments

# %%
clients[0].payments.sort_values(by=['TRANSACTION_DTTM'])
# Out:
#      ID_CPTE  TRANSACTION_AMT     TRANSACTION_DTTM PAYMENT_REVERSAL_XFLG
# 12  99690111            262.5  2015-01-26 00:00:00                     Q
# 11  99690111            303.0  2015-02-26 00:00:00                     Q
# 2   99690111            200.0  2015-03-27 04:00:00                     Q
# 3   99690111             80.8  2015-04-02 00:00:00                     Q
# 0   99690111            208.0  2015-04-26 00:00:00                     Q
# 1   99690111            176.8  2015-05-28 00:00:00                     Q
# 10  99690111            303.0  2015-06-25 00:00:00                     Q
# 7   99690111            618.0  2015-07-27 00:00:00                     Q
# 6   99690111            267.5  2015-08-23 00:00:00                     Q
# 8   99690111            226.6  2015-09-30 00:00:00                     Q
# 9   99690111            244.8  2015-10-27 00:00:00                     Q
# 4   99690111            250.0  2015-11-24 00:00:00                     Q
# 5   99690111            273.0  2015-12-26 00:00:00                     Q

# %% [markdown]
# #### Transactions

# %% [markdown]
# 511 people have had ```PRIOR_CREDIT_LIMIT_AMT``` < 0

# %%
default = performance[performance['Default'] == 1]
default.head()
# Out:
#       ID_CPTE PERIODID_MY  Default
# 18   75780289  2012-12-01        1
# 53   58022132  2013-12-01        1
# 56   25809739  2015-12-01        1
# 72   35143533  2013-12-01        1
# 137  94504449  2012-12-01        1

# %%
answer = []

for cl in set(transactions[transactions['PRIOR_CREDIT_LIMIT_AMT'] < 0]['ID_CPTE']):
    answer.append(int(performance[performance['ID_CPTE'] == cl]['Default']))
    
np.sum(answer)
# Out:
# 305

# %%
clients[499].transactions.sort_values(by=['TRANSACTION_DTTM'])
# Out:
#         ID_CPTE MERCHANT_CATEGORY_XCD  MERCHANT_CITY_NAME  \
# 75821  96393416                    EE             2997570
# 75869  96393416                    VV             1533431
# 75844  96393416                    HH              564476
# 75845  96393416                    HH              564476
# 75862  96393416                    KK              564476
# 75846  96393416                    HH              564476
# 75831  96393416                    EE             2746731
# 75823  96393416                    EE             2997570
# 75806  96393416                    EE             2746731
# 75842  96393416                    EE             2746731
# 75841  96393416                    EE             2997570
# 75865  96393416                    BC              726898
# 75824  96393416                    EE             2746731
# 75859  96393416                    FF             2648365
# 75840  96393416                    EE             2746731
# 75858  96393416                    FF               89373
# 75799  96393416                    DD              427875
# 75864  96393416                    YZ             2997570
# 75800  96393416                    DD              427875
# 75825  96393416                    EE             2780530
# 75826  96393416                    EE             2746731
# 75861  96393416                    KK               89373
# 75797  96393416                    DD              427875
# 75827  96393416                    EE             2997570
# 75783  96393416                    DD              427875
# 75836  96393416                    EE             2746731
# 75781  96393416                    DD              427875
# 75785  96393416                    DD              427875
# 75784  96393416                    DD              427875
# 75828  96393416                    EE             2746731
# ...         ...                   ...                 ...
# 75808  96393416                    EE             2746731
# 75817  96393416                    EE             2746731
# 75780  96393416                    DD              427875
# 75811  96393416                    EE             2746731
# 75786  96393416                    DD              427875
# 75773  96393416                    CC              196304
# 75839  96393416                    EE             2746731
# 75770  96393416                    CC              196304
# 75852  96393416                    FF              196304
# 75833  96393416                    EE             2746731
# 75850  96393416                    FF               89373
# 75803  96393416                    DD              427875
# 75867  96393416                    AE             1533431
# 75853  96393416                    FF              196304
# 75868  96393416                    AE             1533431
# 75818  96393416                    EE             2746731
# 75855  96393416                    FF              196304
# 75779  96393416                    DD              427875
# 75771  96393416                    CC              196304
# 75856  96393416                    FF              196304
# 75819  96393416                    EE             2746731
# 75849  96393416                    FF              196304
# 75835  96393416                    EE             2746731
# 75838  96393416                    EE             2746731
# 75843  96393416                    II             2997570
# 75851  96393416                    FF              196304
# 75829  96393416                    EE             2746731
# 75848  96393416                    FF              196304
# 75854  96393416                    FF              196304
# 75857  96393416                    FF              196304
#
#       MERCHANT_COUNTRY_XCD DECISION_XCD  PRIOR_CREDIT_LIMIT_AMT  \
# 75821                   DP            C                 13470.0
# 75869                   DP            C                 13441.0
# 75844                   DP            C                 13086.0
# 75845                   DP            C                 13080.0
# 75862                   DP            C                 13011.0
# 75846                   DP            C                 13372.0
# 75831                   DP            C                 12975.0
# 75823                   DP            C                 12994.0
# 75806                   DP            C                 12965.0
# 75842                   DP            C                 12888.0
# 75841                   DP            C                 12856.0
# 75865                   DP            C                 12829.0
# 75824                   DP            C                 12861.0
# 75859                   DP            C                 11962.0
# 75840                   DP            C                 11963.0
# 75858                   DP            C                 11856.0
# 75799                   DP            C                 11936.0
# 75864                   DP            C                 11798.0
# 75800                   DP            C                 11754.0
# 75825                   DP            C                 11685.0
# 75826                   DP            C                 11629.0
# 75861                   DP            C                 11661.0
# 75797                   DP            C                 11839.0
# 75827                   DP            C                 11629.0
# 75783                   DP            C                 11603.0
# 75836                   DP            C                 11537.0
# 75781                   DP            C                 11500.0
# 75785                   DP            C                 11435.0
# 75784                   DP            C                 11337.0
# 75828                   DP            C                 11365.0
# ...                    ...          ...                     ...
# 75808                   DP            C                 12853.0
# 75817                   DP            C                 12826.0
# 75780                   DP            C                 12726.0
# 75811                   DP            C                 12782.0
# 75786                   DP            C                 12693.0
# 75773                   DP            C                 12668.0
# 75839                   DP            C                 12651.0
# 75770                   DP            C                 12618.0
# 75852                   DP            C                 12608.0
# 75833                   DP            C                 12582.0
# 75850                   DP            C                 12511.0
# 75803                   DP            C                 12552.0
# 75867                   DP            C                 12400.0
# 75853                   DP            C                 12267.0
# 75868                   DP            C                 12415.0
# 75818                   DP            C                 12478.0
# 75855                   DP            C                 12437.0
# 75779                   DP            C                 12404.0
# 75771                   DP            C                 12413.0
# 75856                   DP            C                 12387.0
# 75819                   DP            C                 12327.0
# 75849                   DP            C                 12238.0
# 75835                   DP            C                  8845.0
# 75838                   DP            C                 12210.0
# 75843                   DP            C                 12115.0
# 75851                   DP            C                  8824.0
# 75829                   DP            C                  8758.0
# 75848                   DP            C                  8804.0
# 75854                   DP            C                  9300.0
# 75857                   DP            C                  9226.0
#
#        TRANSACTION_AMT TRANSACTION_CATEGORY_XCD     TRANSACTION_DTTM  \
# 75821            30.45                        E  2013-01-03 12:00:00
# 75869            73.14                        E  2013-01-14 12:00:00
# 75844             5.05                        E  2013-01-14 16:00:00
# 75845            70.72                        E  2013-01-14 16:00:00
# 75862            18.90                        E  2013-01-16 16:00:00
# 75846           307.09                        E  2013-01-16 16:00:00
# 75831            11.77                        E  2013-01-27 20:00:00
# 75823            18.00                        E  2013-01-28 12:00:00
# 75806            80.08                        E  2013-02-19 16:00:00
# 75842            31.93                        E  2013-02-19 16:00:00
# 75841            29.58                        E  2013-02-21 16:00:00
# 75865           926.62                        E  2013-03-09 12:00:00
# 75824            32.32                        E  2013-03-10 16:00:00
# 75859            24.00                        E  2013-03-12 20:00:00
# 75840            28.08                        E  2013-03-16 20:00:00
# 75858            60.90                        E  2013-03-17 16:00:00
# 75799            86.67                        E  2013-03-17 16:00:00
# 75864            45.15                        E  2013-03-21 12:00:00
# 75800            72.10                        E  2013-03-21 16:00:00
# 75825            23.92                        E  2013-03-25 12:00:00
# 75826            69.68                        E  2013-03-26 16:00:00
# 75861            33.28                        E  2013-03-28 16:00:00
# 75797            75.26                        E  2013-03-31 16:00:00
# 75827            27.82                        E  2013-04-04 12:00:00
# 75783            67.00                        E  2013-04-04 16:00:00
# 75836            38.16                        E  2013-04-11 20:00:00
# 75781            70.62                        E  2013-04-12 16:00:00
# 75785            72.45                        E  2013-04-14 16:00:00
# 75784            66.30                        E  2013-04-15 16:00:00
# 75828            27.00                        E  2013-04-16 12:00:00
# ...                ...                      ...                  ...
# 75808            26.26                        E  2013-10-29 20:00:00
# 75817            46.35                        E  2013-11-02 20:00:00
# 75780            36.38                        E  2013-11-04 16:00:00
# 75811            57.00                        E  2013-11-04 20:00:00
# 75786            26.50                        E  2013-11-06 16:00:00
# 75773            16.32                        E  2013-11-06 16:00:00
# 75839            34.34                        E  2013-11-07 12:00:00
# 75770            10.60                        E  2013-11-08 12:00:00
# 75852            27.30                        E  2013-11-12 20:00:00
# 75833            30.60                        E  2013-11-14 12:00:00
# 75850           133.12                        E  2013-11-16 12:00:00
# 75803            40.40                        E  2013-11-17 16:00:00
# 75867           133.00                        E  2013-11-22 16:00:00
# 75853            67.41                        E  2013-11-23 12:00:00
# 75868            15.75                        E  2013-11-24 16:00:00
# 75818            44.94                        E  2013-12-02 16:00:00
# 75855            24.72                        E  2013-12-03 16:00:00
# 75779            16.32                        E  2013-12-10 16:00:00
# 75771            10.50                        E  2013-12-10 16:00:00
# 75856            59.59                        E  2013-12-12 16:00:00
# 75819            94.34                        E  2013-12-18 12:00:00
# 75849            30.45                        E  2013-12-20 16:00:00
# 75835            22.44                        E  2013-12-21 16:00:00
# 75838            96.82                        E  2013-12-22 16:00:00
# 75843          3296.00                        E  2013-12-23 16:00:00
# 75851            20.60                        E  2013-12-24 16:00:00
# 75829            42.00                        E  2013-12-26 12:00:00
# 75848            45.45                        E  2013-12-27 12:00:00
# 75854            55.08                        E  2013-12-28 20:00:00
# 75857            48.76                        E  2014-01-02 12:00:00
#
#       TRANSACTION_TYPE_XCD SICGROUP
# 75821                    F       AX
# 75869                    F       AL
# 75844                    F       AE
# 75845                    F       AE
# 75862                    F       AT
# 75846                    F       AE
# 75831                    F       AX
# 75823                    F       AX
# 75806                    F       AX
# 75842                    F       AX
# 75841                    F       AX
# 75865                    F       AA
# 75824                    F       AX
# 75859                    F       BA
# 75840                    F       AX
# 75858                    F       BA
# 75799                    F       AC
# 75864                    F       AG
# 75800                    F       AC
# 75825                    F       AX
# 75826                    F       AX
# 75861                    F       AT
# 75797                    F       AC
# 75827                    F       AX
# 75783                    F       AC
# 75836                    F       AX
# 75781                    F       AC
# 75785                    F       AC
# 75784                    F       AC
# 75828                    F       AX
# ...                    ...      ...
# 75808                    F       AX
# 75817                    F       AX
# 75780                    F       AC
# 75811                    F       AX
# 75786                    F       AC
# 75773                    F       AP
# 75839                    F       AX
# 75770                    F       AP
# 75852                    F       BA
# 75833                    F       AX
# 75850                    F       BA
# 75803                    F       AC
# 75867                    F       AU
# 75853                    F       BA
# 75868                    F       AU
# 75818                    F       AX
# 75855                    F       BA
# 75779                    F       AC
# 75771                    F       AP
# 75856                    F       BA
# 75819                    F       AX
# 75849                    F       BA
# 75835                    F       AX
# 75838                    F       AX
# 75843                    F       AM
# 75851                    F       BA
# 75829                    F       AX
# 75848                    F       BA
# 75854                    F       BA
# 75857                    F       BA
#
# [102 rows x 11 columns]

# %%
payments[payments['PAYMENT_REVERSAL_XFLG'] == 'N']
# Out:
#          ID_CPTE  TRANSACTION_AMT     TRANSACTION_DTTM PAYMENT_REVERSAL_XFLG
# 2464    13888046           555.33  2012-01-05 12:00:00                     N
# 4121    16989442         27952.68  2014-07-01 12:00:00                     N
# 33905   60095553           525.00  2016-05-30 00:00:00                     N
# 46169   13461194          1010.00  2014-05-18 12:00:00                     N
# 55058   43175568          1008.06  2015-05-02 12:00:00                     N
# 55436   82092975           159.00  2015-06-16 12:00:00                     N
# 61481   37344975           260.00  2012-04-04 12:00:00                     N
# 61483   37344975           408.00  2012-04-03 12:00:00                     N
# 63529   41208217           515.00  2014-04-03 12:00:00                     N
# 67683   42198845          6464.28  2014-07-06 12:00:00                     N
# 68954   24178402           107.00  2012-08-31 12:00:00                     N
# 82335   10791561          1272.00  2016-01-25 00:00:00                     N
# 97407   80967033           463.50  2015-05-06 12:00:00                     N
# 98634   25123491           260.00  2013-06-10 12:00:00                     N
# 99294   90557588           100.00  2014-04-05 12:00:00                     N
# 124862  81589449           715.02  2014-10-05 12:00:00                     N
# 133743  88064779          1501.44  2016-07-04 00:00:00                     N
# 140471  89306365         10200.00  2014-01-17 00:00:00                     N
# 144193  71954869         12190.00  2015-08-23 12:00:00                     N
# 147008  88305152          3186.82  2014-06-08 12:00:00                     N
# 164786  13929828          5407.50  2014-08-21 12:00:00                     N
# 184986  40055178         50500.00  2014-03-22 12:00:00                     N
# 213895  32908705          1040.00  2014-07-09 12:00:00                     N
# 217832  78763942          2850.34  2016-03-04 12:00:00                     N
# 219976  72460159         13375.00  2015-05-28 12:00:00                     N
# 229686  15561755          1244.88  2013-10-13 12:00:00                     N
# 249990  70612656         10300.00  2013-12-06 12:00:00                     N

# %%
for i in range(6):
    print(list(facturation['DelqCycle']).count(i))
# Out:
# 157173
# 7899
# 1285
# 151
# 30
# 5

# %%
transactions[transactions['ID_CPTE'] == a[3]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-7fa3da6d6c6e> in <module>()
# ----> 1 transactions[transactions['ID_CPTE'] == a[3]]
#
# NameError: name 'a' is not defined

# %%
no_transaction_people = list(set(performance['ID_CPTE']) - set(transactions['ID_CPTE']))
len(no_transaction_people)

# %%
set([1, 2, 3]).intersection(set([1, 2, 4]))

# %%
a = set(performance[performance['Default'] == 1]['ID_CPTE'])

# %%
b = set(performance['ID_CPTE']) - set(transactions['ID_CPTE'])
len(b)

# %%
no_transaction_default = list(a.intersection(b))

# %%
performance[performance['ID_CPTE'] == no_transaction_default[3]]

# %%
payments[payments['ID_CPTE'] == no_transaction_default[3]].sort_values(by='TRANSACTION_DTTM')

# %%
facturation[facturation['ID_CPTE'] == no_transaction_default[7]].sort_values(by='PERIODID_MY')

# %%
surpassed_cred_limit = []

for cl in clients:
    if (cl.facturation['CurrentTotalBalance'] > cl.facturation['CreditLimit']).any():
        surpassed_cred_limit.append(cl.customer_id)

# %%
(clients[7].facturation['CurrentTotalBalance'] > clients[7].facturation['CreditLimit']).any()

# %%
surpassed_no_def = list(set(surpassed_cred_limit).intersection(performance[performance['Default'] == 0]['ID_CPTE']))

# %%
facturation[facturation['ID_CPTE'] == surpassed_no_def[7]].sort_values(by='PERIODID_MY')

# %%
payments[payments['ID_CPTE'] == surpassed_no_def[7]].sort_values(by='TRANSACTION_DTTM')

# %%
transactions[transactions['ID_CPTE'] == surpassed_no_def[4]].sort_values(by='TRANSACTION_DTTM')

# %%
performance[performance['ID_CPTE'] == surpassed_no_def[4]]

# %%
len(surpassed_no_def)/len(surpassed_cred_limit)

# %%
out = []
for cl in clients:
    if sum(cl.facturation['CashBalance']) != 0:
        out.append(max(cl.facturation['CashBalance']/cl.facturation['CreditLimit']))
        
min(out)
