# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
performance  = pd.read_csv('train/performance_train.csv', index_col= False)
facturation  = pd.read_csv('train/facturation_train.csv', index_col= False)
paiements    = pd.read_csv('train/paiements_train.csv', index_col= False)
transactions = pd.read_csv('train/transactions_train.csv', index_col= False)

print(sum(performance['Default'])/len(performance))
# Out:
# 0.19336134453781512

# %%
performance["PERIODID_MY"]= pd.to_datetime(performance["PERIODID_MY"]).dt.year

# %%
performance.drop
# Out:
# <bound method DataFrame.drop of         ID_CPTE  PERIODID_MY  Default
# 0      99690111         2015        0
# 1      57427180         2012        0
# 2      29617912         2015        0
# 3      61632809         2015        0
# 4      14117855         2013        0
# 5      23700394         2013        0
# 6      27881705         2012        0
# 7      46100731         2012        0
# 8      58512689         2014        0
# 9      24661392         2016        0
# 10     39254190         2016        0
# 11     95779116         2015        0
# 12     26016069         2016        0
# 13     47119980         2013        0
# 14     55240199         2013        0
# 15     35559686         2014        0
# 16     71856405         2016        0
# 17     75085501         2015        0
# 18     75780289         2012        1
# 19     74010769         2015        0
# 20     90088004         2013        0
# 21     43551724         2015        0
# 22     68131233         2013        0
# ...

# %%
facturation.head(25)
# Out:
#      ID_CPTE PERIODID_MY StatementDate  CurrentTotalBalance  CashBalance  \
# 0   99690111  2015-05-01    2015-05-03              8497.84      4293.12
# 1   99690111  2014-11-01    2014-11-03               866.00         0.00
# 2   99690111  2015-06-01    2015-05-31             10790.95      5224.44
# 3   99690111  2015-10-01    2015-10-04             12388.46      4786.08
# 4   99690111  2015-11-01    2015-11-02             12746.50      4818.48
# 5   99690111  2015-08-01    2015-08-02             10610.05      4753.35
# 6   99690111  2015-09-01    2015-08-30             11417.12      4616.46
# 7   99690111  2014-12-01    2014-12-03              1151.85         0.00
# 8   99690111  2015-02-01    2015-01-31              4045.67      1148.45
# 9   99690111  2015-12-01    2015-11-30             13119.60      4791.44
# 10  99690111  2015-01-01    2015-01-02              2298.96       350.00
# 11  99690111  2015-03-01    2015-03-03              5926.20      2567.25
# ...

# %%
paiements.head(25)
# Out:
#      ID_CPTE  TRANSACTION_AMT     TRANSACTION_DTTM PAYMENT_REVERSAL_XFLG
# 0   99690111           208.00  2015-04-26 00:00:00                     Q
# 1   99690111           176.80  2015-05-28 00:00:00                     Q
# 2   99690111           200.00  2015-03-27 04:00:00                     Q
# 3   99690111            80.80  2015-04-02 00:00:00                     Q
# 4   99690111           250.00  2015-11-24 00:00:00                     Q
# 5   99690111           273.00  2015-12-26 00:00:00                     Q
# 6   99690111           267.50  2015-08-23 00:00:00                     Q
# 7   99690111           618.00  2015-07-27 00:00:00                     Q
# 8   99690111           226.60  2015-09-30 00:00:00                     Q
# 9   99690111           244.80  2015-10-27 00:00:00                     Q
# 10  99690111           303.00  2015-06-25 00:00:00                     Q
# 11  99690111           303.00  2015-02-26 00:00:00                     Q
# ...

# %%
transactions
# Out:
#          ID_CPTE MERCHANT_CATEGORY_XCD  MERCHANT_CITY_NAME  \
# 0       99690111                     A              365767
# 1       99690111                     L             2635650
# 2       99690111                     L             2635650
# 3       99690111                     J              680536
# 4       99690111                     J              680536
# 5       99690111                     J              680536
# 6       99690111                     J              680536
# 7       99690111                     J              680536
# 8       99690111                     J              680536
# 9       99690111                     J              680536
# 10      99690111                     J              680536
# 11      99690111                     J              680536
# 12      99690111                     J              680536
# 13      99690111                     J              680536
# 14      99690111                     J              680536
# ...

# %%
transactions.loc[transactions["ID_CPTE"] == 99690111 and transactions["MERCHANT_CATEGORY_XCD"]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-b5336429df03> in <module>()
# ----> 1 transactions.loc[transactions["ID_CPTE"] == 99690111 and transactions["MERCHANT_CATEGORY_XCD"]]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1571         raise ValueError("The truth value of a {0} is ambiguous. "
#    1572                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1573                          .format(self.__class__.__name__))
#    1574
#    1575     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
transaction_numbers = transactions['ID_CPTE'].value_counts()

# %%
print('performance length:', len(performance))
print('facturation length:', len(facturation))
print('paiements length:', len(paiements))
print('transactions length:', len(transactions))
# Out:
# performance length: 11900
# facturation length: 166543
# paiements length: 292320
# transactions length: 690730

# %%
class customer:
    
    def __init__(self, default, assessment, facturation, paiements, transactions):
        
        self.default      = default
        self.assessment   = assessment
        self.facturation  = facturation
        self.paiements    = paiements
        self.transactions = transactions

# %%
customer_ids = performance['ID_CPTE']

# %%
merge_info = pd.merge(pd.merge(pd.merge(performance,facturation),paiements),transactions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-1c41c292b336> in <module>()
# ----> 1 merge_info = pd.merge(pd.merge(pd.merge(performance,facturation),paiements),transactions)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      58                          right_index=right_index, sort=sort, suffixes=suffixes,
#      59                          copy=copy, indicator=indicator,
# ---> 60                          validate=validate)
#      61     return op.get_result()
#      62
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...

# %%
response = merge_info["Default"]
features = merge_info.drop("Default", axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-1b0b04d0ee92> in <module>()
# ----> 1 response = merge_info["Default"]
#       2 features = merge_info.drop("Default", axis=1)
#
# NameError: name 'merge_info' is not defined

# %%
merge_info.head(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-44e6484af6f8> in <module>()
# ----> 1 merge_info.head(50)
#
# NameError: name 'merge_info' is not defined

# %%
merge_info.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-9f6f8569a9e1> in <module>()
# ----> 1 merge_info.shape
#
# NameError: name 'merge_info' is not defined
